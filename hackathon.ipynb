# %%
from pytube import YouTube
import cv2
import os

def extract_frames(youtube_url, output_folder='frames'):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    yt = YouTube(youtube_url)
    stream = yt.streams.get_highest_resolution()
    video_path = stream.download()

    vidcap = cv2.VideoCapture(video_path)
    success, image = vidcap.read()
    count = 0
    while success:
        cv2.imwrite(os.path.join(output_folder, f"frame{count}.jpg"), image)
        success, image = vidcap.read()
        count += 1

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyCqZ41T0d3I5UiDe6PxSqAYEeErDREQ-tU")

def generate_enthusiasm_evaluation(enthusiasm_score):
    model = genai.GenerativeModel('gemini-pro')
    prompt = f"Based on a facial analysis of a person in a video, their enthusiasm score is {enthusiasm_score} out of a possible 2. Please provide a brief evaluation of their likely level of enthusiasm, considering that a higher score indicates greater enthusiasm."
    response = model.generate_content(prompt)
    return response.text

# %%
GEMINI_API_KEY='AIzaSyCqZ41T0d3I5UiDe6PxSqAYEeErDREQ-tU'
